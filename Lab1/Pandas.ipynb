# %% [markdown]
# <a href="https://colab.research.google.com/github/KDS-Creator/PHY3638_Machine_Learning/blob/main/Lab1/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Importing

# %%
import pandas as pd

# %%
data = pd.read_csv('7_OneCatOneNum.csv')
print(data.head())
# Out:
#           Country    Value
# 0   United States  12394.0
# 1          Russia   6148.0
# 2   Germany (FRG)   1653.0
# 3          France   2162.0
# 4  United Kingdom   1214.0

# %%
# Series
data = [1, 3, 4, 6]
table = pd.Series(data)
print(table)
# Out:
# 0    1
# 1    3
# 2    4
# 3    6
# dtype: int64

# %%
data = [1, 3, 4, 6]
table = pd.Series(data, index = ['Math', 'Chem', 'Physic', 'Art'])
print(table)
# Out:
# Math      1
# Chem      3
# Physic    4
# Art       6
# dtype: int64

# %%
print(table['Art'])
# Out:
# 6

# %%
data = {"Height": [1.8, 1.6, 1.5],
        "Weight": [50, 40, 45]}

# Load data into a DataFrame object:
df = pd.DataFrame(data)
print(df)
# Out:
#    Height  Weight
# 0     1.8      50
# 1     1.6      40
# 2     1.5      45

# %%
# Loc and iloc
data = {"Height": [1.8, 1.6, 1.5],
        "Weight": [50, 40, 45]}

# Load data into a DataFrame object:
df = pd.DataFrame(data, index = ['An', 'Tu', 'Tuan'])
print(df)
# Out:
#       Height  Weight
# An       1.8      50
# Tu       1.6      40
# Tuan     1.5      45

# %%
df.loc['Tu']
# Out:
# Height     1.6
# Weight    40.0
# Name: Tu, dtype: float64

# %%
df.iloc[1]
# Out:
# Height     1.6
# Weight    40.0
# Name: Tu, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, An to Tuan
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  3 non-null      float64
#  1   Weight  3 non-null      int64
# dtypes: float64(1), int64(1)
# memory usage: 180.0+ bytes

# %%
df.columns
# Out:
# Index(['Height', 'Weight'], dtype='object')

# %%
data = pd.read_csv("7_OneCatOneNum.csv")
data
# Out:
#                 Country    Value
# 0         United States  12394.0
# 1                Russia   6148.0
# 2         Germany (FRG)   1653.0
# 3                France   2162.0
# 4        United Kingdom   1214.0
# 5                 China   1131.0
# 6          Soviet Union      NaN
# 7           Netherlands   1167.0
# 8                 Italy    660.0
# 9                Israel   1263.0
# 10              Ukraine    240.0
# 11                Spain    814.0
# 12               Sweden     83.0
# 13          Switzerland    186.0
# 14               Canada     87.0
# 15          South Korea    587.0
# 16              Belarus     23.0
# 17               Norway    134.0
# 18               Turkey    244.0
# 19         South Africa     74.0
# 20       Czech Republic    110.0
# 21               Poland      3.0
# 22              Belgium     12.0
# 23            Australia     97.0
# 24               Brazil     45.0
# 25       Czechoslovakia      NaN
# 26          North Korea      NaN
# ...

# %%
data.dropna(inplace=True)
data
# Out:
#                 Country    Value
# 0         United States  12394.0
# 1                Russia   6148.0
# 2         Germany (FRG)   1653.0
# 3                France   2162.0
# 4        United Kingdom   1214.0
# 5                 China   1131.0
# 7           Netherlands   1167.0
# 8                 Italy    660.0
# 9                Israel   1263.0
# 10              Ukraine    240.0
# 11                Spain    814.0
# 12               Sweden     83.0
# 13          Switzerland    186.0
# 14               Canada     87.0
# 15          South Korea    587.0
# 16              Belarus     23.0
# 17               Norway    134.0
# 18               Turkey    244.0
# 19         South Africa     74.0
# 20       Czech Republic    110.0
# 21               Poland      3.0
# 22              Belgium     12.0
# 23            Australia     97.0
# 24               Brazil     45.0
# 27              Finland     58.0
# 29                Japan      2.0
# 30             Slovakia     22.0
# ...

# %%
data = pd.read_csv("7_OneCatOneNum.csv")
data.fillna(0, inplace=True)
data
# Out:
#                 Country    Value
# 0         United States  12394.0
# 1                Russia   6148.0
# 2         Germany (FRG)   1653.0
# 3                France   2162.0
# 4        United Kingdom   1214.0
# 5                 China   1131.0
# 6          Soviet Union      0.0
# 7           Netherlands   1167.0
# 8                 Italy    660.0
# 9                Israel   1263.0
# 10              Ukraine    240.0
# 11                Spain    814.0
# 12               Sweden     83.0
# 13          Switzerland    186.0
# 14               Canada     87.0
# 15          South Korea    587.0
# 16              Belarus     23.0
# 17               Norway    134.0
# 18               Turkey    244.0
# 19         South Africa     74.0
# 20       Czech Republic    110.0
# 21               Poland      3.0
# 22              Belgium     12.0
# 23            Australia     97.0
# 24               Brazil     45.0
# 25       Czechoslovakia      0.0
# 26          North Korea      0.0
# ...

# %%
data = pd.read_csv('10_OneNumSevCatSubgroupsSevObs.csv')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
grouped = data.groupby('sex')
grouped.count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_26, *['total_bill'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
# ...

# %%
# Rename
data = {"Height": [1.8, 1.6, 1.5],
        "Weight": [50, 40, 45]}

# Load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    Height  Weight
# 0     1.8      50
# 1     1.6      40
# 2     1.5      45

# %%
df.rename(columns={'Height': 'Chieu_Cao'}, inplace=True)

# %%
df
# Out:
#    Chieu_Cao  Weight
# 0        1.8      50
# 1        1.6      40
# 2        1.5      45

# %%
data = pd.read_csv('10_OneNumSevCatSubgroupsSevObs.csv')
data.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
data['total_bill'].sum()
# Out:
# 4827.77

# %%
data['tip'].sum()
# Out:
# 731.5799999999999

# %%
data['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
data['total_bill'].median()
# Out:
# 17.795

# %%
data['total_bill'].std()
# Out:
# 8.902411954856856

# %%
data['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
data['tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
sex_group = data.groupby('sex')
sex_group.count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %%
smoker_group = data.groupby('smoker')
smoker_group.count()
# Out:
#         total_bill  tip  sex  day  time  size
# smoker
# No             151  151  151  151   151   151
# Yes             93   93   93   93    93    93
